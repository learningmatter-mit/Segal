# %%
from ase import Atoms
from ase.calculators.emt import EMT
from ase.db import connect
import clease

from clease.tools import update_db
from clease import Concentration
from clease import CEBulk
from clease import Evaluate
from clease import NewStructures
from clease.calculator import Clease
from clease.calculator import attach_calculator
from ase.eos import EquationOfState
import sys
from ase.constraints import StrainFilter
from ase.optimize import BFGS
from mpl_toolkits.mplot3d import Axes3D 

import matplotlib.pyplot as plt
import numpy as np

# %%
#from clease.settings import CEBulk, Concentration
conc = Concentration(basis_elements=[['Au', 'Cu']])

import json
with open('eci_final.json') as json_file: 
    eci = json.load(json_file)

settings = CEBulk(crystalstructure='fcc',
                   a=4.09,
                   size=[8,4,4],
                   concentration=conc,
                   db_name="auni_ar.db",
                   max_cluster_size=4,
                   max_cluster_dia=[6.0, 4.5, 4.5])

atoms = settings.atoms.copy()
atoms = attach_calculator(settings, atoms=atoms, eci=eci)

# %%
from clease.montecarlo.observers import ConcentrationObserver
obs = ConcentrationObserver(atoms, element='Au')

# %%
from clease.montecarlo import SGCMonteCarlo
mc = SGCMonteCarlo(atoms, 50, symbols=['Au', 'Cu'])

# %%
from clease.montecarlo import BinnedBiasPotential
from clease.montecarlo import MetaDynamicsSampler

bias = BinnedBiasPotential(xmin=0.0 - (1.0/256), xmax=1.0 + (1.0/256), nbins=129, getter=obs)

# %%
def get_free_energy(t):
    mod = 10000
    obs = ConcentrationObserver(atoms, element='Au')
    bias = BinnedBiasPotential(xmin=0.0 - (1.0/256), xmax=1.0 + (1.0/256), nbins=129, getter=obs)
    while mod >= 0.0001:
        obs = ConcentrationObserver(atoms, element='Au')
        mc = SGCMonteCarlo(atoms, t, symbols=['Au', 'Cu'])
        meta_dyn = MetaDynamicsSampler(mc=mc, bias=bias, flat_limit=0.8, mod_factor=mod,
                                       fname='aucu_metadyn.json')
        meta_dyn.run(max_sweeps=20000)
        
        
        with open('aucu_metadyn.json', 'r') as f:
            data = json.load(f)
            #print(data)
        bias.from_dict(data['bias_pot'])
        
        mod /= 2
    
    concs = np.linspace(0,1.0,129)
    new_bias_values = np.zeros((129))
    tmp = -np.asarray(bias.values)
    for i in range(129):
        new_bias_values[i] = tmp[i] - ((concs[i])*(tmp[-1]) + (1-concs[i])*(tmp[0])    )
    return new_bias_values/128

# %%
temps = np.linspace(200,1200,41)

pots = np.zeros((len(temps),129))

count = 0
for t in temps:
    pots[count,:] = get_free_energy(t)
    count += 1
# Out:
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1540 Average visits: 1.53e+03. Min/avg: 4.09e-01 x: 3.91e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1529 Average visits: 1.52e+03. Min/avg: 4.29e-01 x: 1.80e-01
# Sweep no. 3070 Average visits: 3.04e+03. Min/avg: 5.97e-01 x: 8.98e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1519 Average visits: 1.52e+03. Min/avg: 2.11e-02 x: 8.91e-01
# Sweep no. 3050 Average visits: 3.04e+03. Min/avg: 3.67e-01 x: 5.47e-02
# Sweep no. 4589 Average visits: 4.57e+03. Min/avg: 5.23e-01 x: 8.52e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1517 Average visits: 1.51e+03. Min/avg: 8.63e-03 x: 6.25e-01
# Sweep no. 3050 Average visits: 3.03e+03. Min/avg: 3.61e-01 x: 8.75e-01
# Sweep no. 4561 Average visits: 4.52e+03. Min/avg: 7.09e-01 x: 2.11e-01
# Sweep no. 6092 Average visits: 6.05e+03. Min/avg: 6.14e-01 x: 4.22e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1542 Average visits: 1.54e+03. Min/avg: 0.00e+00 x: 3.75e-01
# Sweep no. 3087 Average visits: 3.09e+03. Min/avg: 0.00e+00 x: 2.50e-01
# Sweep no. 4645 Average visits: 4.64e+03. Min/avg: 7.03e-02 x: 1.00e+00
# Sweep no. 6156 Average visits: 6.12e+03. Min/avg: 5.40e-01 x: 5.47e-01
# Sweep no. 7707 Average visits: 7.67e+03. Min/avg: 4.31e-01 x: 1.88e-01
# Sweep no. 9284 Average visits: 9.23e+03. Min/avg: 6.39e-01 x: 5.78e-01
# Sweep no. 10824 Average visits: 1.08e+04. Min/avg: 7.57e-01 x: 9.22e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1517 Average visits: 1.51e+03. Min/avg: 7.27e-03 x: 5.47e-02
# Sweep no. 2991 Average visits: 2.98e+03. Min/avg: 1.01e-01 x: 7.66e-01
# Sweep no. 4522 Average visits: 4.49e+03. Min/avg: 2.99e-01 x: 5.16e-01
# Sweep no. 6065 Average visits: 6.02e+03. Min/avg: 5.36e-01 x: 9.30e-01
# Sweep no. 7623 Average visits: 7.58e+03. Min/avg: 6.95e-01 x: 3.91e-02
# Sweep no. 9164 Average visits: 9.12e+03. Min/avg: 5.77e-01 x: 6.33e-01
# Sweep no. 10720 Average visits: 1.07e+04. Min/avg: 7.15e-01 x: 2.97e-01
# Sweep no. 12264 Average visits: 1.22e+04. Min/avg: 6.24e-01 x: 4.06e-01
# Sweep no. 13784 Average visits: 1.37e+04. Min/avg: 7.08e-01 x: 8.67e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1550 Average visits: 1.53e+03. Min/avg: 0.00e+00 x: 9.38e-01
# Sweep no. 3133 Average visits: 3.12e+03. Min/avg: 2.67e-01 x: 6.48e-01
# Sweep no. 4638 Average visits: 4.55e+03. Min/avg: 1.83e-01 x: 5.70e-01
# Sweep no. 6123 Average visits: 6.00e+03. Min/avg: 1.39e-01 x: 4.84e-01
# Sweep no. 7665 Average visits: 7.55e+03. Min/avg: 4.83e-01 x: 3.91e-02
# Sweep no. 9234 Average visits: 9.12e+03. Min/avg: 6.24e-01 x: 3.83e-01
# Sweep no. 10796 Average visits: 1.07e+04. Min/avg: 7.38e-01 x: 2.27e-01
# Sweep no. 12369 Average visits: 1.23e+04. Min/avg: 6.61e-01 x: 5.94e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1549 Average visits: 1.55e+03. Min/avg: 0.00e+00 x: 8.36e-01
# Sweep no. 3081 Average visits: 3.06e+03. Min/avg: 0.00e+00 x: 2.58e-01
# Sweep no. 4616 Average visits: 4.59e+03. Min/avg: 1.51e-01 x: 3.91e-01
# Sweep no. 6153 Average visits: 6.13e+03. Min/avg: 2.93e-01 x: 2.11e-01
# Sweep no. 7695 Average visits: 7.67e+03. Min/avg: 2.49e-01 x: 2.66e-01
# Sweep no. 9156 Average visits: 9.13e+03. Min/avg: 2.09e-01 x: 3.28e-01
# Sweep no. 10597 Average visits: 1.05e+04. Min/avg: 4.88e-01 x: 8.59e-01
# Sweep no. 12065 Average visits: 1.20e+04. Min/avg: 7.01e-01 x: 4.22e-01
# Sweep no. 13540 Average visits: 1.35e+04. Min/avg: 6.25e-01 x: 1.33e-01
# Sweep no. 15097 Average visits: 1.50e+04. Min/avg: 5.60e-01 x: 5.23e-01
# Sweep no. 16693 Average visits: 1.66e+04. Min/avg: 6.75e-01 x: 7.34e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1560 Average visits: 1.56e+03. Min/avg: 0.00e+00 x: 8.28e-01
# Sweep no. 3106 Average visits: 3.11e+03. Min/avg: 0.00e+00 x: 3.12e-02
# Sweep no. 4657 Average visits: 4.66e+03. Min/avg: 0.00e+00 x: 7.97e-01
# Sweep no. 6238 Average visits: 6.24e+03. Min/avg: 0.00e+00 x: 4.45e-01
# Sweep no. 7852 Average visits: 7.78e+03. Min/avg: 4.60e-01 x: 6.88e-01
# Sweep no. 9437 Average visits: 9.36e+03. Min/avg: 4.71e-01 x: 1.41e-01
# Sweep no. 11009 Average visits: 1.09e+04. Min/avg: 5.47e-01 x: 3.52e-01
# Sweep no. 12596 Average visits: 1.25e+04. Min/avg: 6.01e-01 x: 8.67e-01
# Sweep no. 14197 Average visits: 1.41e+04. Min/avg: 5.33e-01 x: 5.47e-01
# Sweep no. 15773 Average visits: 1.56e+04. Min/avg: 6.00e-01 x: 0.00e+00
# Sweep no. 17365 Average visits: 1.72e+04. Min/avg: 6.36e-01 x: 4.84e-01
# Sweep no. 18932 Average visits: 1.88e+04. Min/avg: 6.90e-01 x: 8.59e-02
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1570 Average visits: 1.56e+03. Min/avg: 5.84e-01 x: 8.59e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1596 Average visits: 1.58e+03. Min/avg: 5.55e-01 x: 1.72e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1579 Average visits: 1.57e+03. Min/avg: 5.09e-01 x: 7.81e-03
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1613 Average visits: 1.61e+03. Min/avg: 1.23e-01 x: 2.27e-01
# Sweep no. 3156 Average visits: 3.13e+03. Min/avg: 6.31e-01 x: 9.38e-01
# Sweep no. 4779 Average visits: 4.74e+03. Min/avg: 7.97e-01 x: 5.47e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1653 Average visits: 1.65e+03. Min/avg: 1.70e-01 x: 2.11e-01
# Sweep no. 3241 Average visits: 3.22e+03. Min/avg: 5.52e-01 x: 3.59e-01
# Sweep no. 4774 Average visits: 4.74e+03. Min/avg: 7.09e-01 x: 8.67e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1583 Average visits: 1.58e+03. Min/avg: 0.00e+00 x: 4.14e-01
# Sweep no. 3143 Average visits: 3.13e+03. Min/avg: 2.48e-01 x: 5.39e-01
# Sweep no. 4744 Average visits: 4.73e+03. Min/avg: 3.13e-01 x: 7.27e-01
# Sweep no. 6296 Average visits: 6.26e+03. Min/avg: 6.67e-01 x: 7.89e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1598 Average visits: 1.60e+03. Min/avg: 1.57e-01 x: 9.22e-01
# Sweep no. 3221 Average visits: 3.20e+03. Min/avg: 5.80e-01 x: 1.02e-01
# Sweep no. 4831 Average visits: 4.81e+03. Min/avg: 4.34e-01 x: 3.75e-01
# Sweep no. 6406 Average visits: 6.37e+03. Min/avg: 6.27e-01 x: 9.45e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1594 Average visits: 1.59e+03. Min/avg: 0.00e+00 x: 1.64e-01
# Sweep no. 3216 Average visits: 3.22e+03. Min/avg: 0.00e+00 x: 4.38e-01
# Sweep no. 4848 Average visits: 4.80e+03. Min/avg: 4.73e-01 x: 7.19e-01
# Sweep no. 6473 Average visits: 6.40e+03. Min/avg: 4.82e-01 x: 2.27e-01
# Sweep no. 8089 Average visits: 8.02e+03. Min/avg: 5.44e-01 x: 5.00e-01
# Sweep no. 9766 Average visits: 9.69e+03. Min/avg: 4.50e-01 x: 1.33e-01
# Sweep no. 11384 Average visits: 1.13e+04. Min/avg: 5.69e-01 x: 9.77e-01
# Sweep no. 12845 Average visits: 1.27e+04. Min/avg: 6.85e-01 x: 9.06e-01
# Sweep no. 14338 Average visits: 1.42e+04. Min/avg: 6.49e-01 x: 3.44e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1564 Average visits: 1.56e+03. Min/avg: 1.61e-02 x: 3.12e-02
# Sweep no. 2992 Average visits: 2.99e+03. Min/avg: 1.61e-02 x: 8.59e-02
# Sweep no. 4366 Average visits: 4.35e+03. Min/avg: 2.07e-01 x: 8.75e-01
# Sweep no. 5888 Average visits: 5.87e+03. Min/avg: 2.77e-01 x: 8.05e-01
# Sweep no. 7423 Average visits: 7.36e+03. Min/avg: 2.21e-01 x: 8.12e-01
# Sweep no. 8833 Average visits: 8.77e+03. Min/avg: 2.54e-01 x: 2.34e-01
# Sweep no. 10205 Average visits: 1.01e+04. Min/avg: 4.65e-01 x: 3.05e-01
# Sweep no. 11691 Average visits: 1.16e+04. Min/avg: 5.92e-01 x: 8.59e-02
# Sweep no. 13210 Average visits: 1.31e+04. Min/avg: 5.56e-01 x: 2.50e-01
# Sweep no. 14708 Average visits: 1.46e+04. Min/avg: 4.99e-01 x: 6.56e-01
# Sweep no. 16217 Average visits: 1.61e+04. Min/avg: 6.40e-01 x: 4.84e-01
# Sweep no. 17771 Average visits: 1.77e+04. Min/avg: 5.84e-01 x: 4.69e-02
# Sweep no. 19281 Average visits: 1.92e+04. Min/avg: 6.72e-01 x: 9.30e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1475 Average visits: 1.45e+03. Min/avg: 0.00e+00 x: 5.55e-01
# Sweep no. 2970 Average visits: 2.95e+03. Min/avg: 0.00e+00 x: 7.19e-01
# Sweep no. 4489 Average visits: 4.45e+03. Min/avg: 0.00e+00 x: 4.84e-01
# Sweep no. 5901 Average visits: 5.86e+03. Min/avg: 0.00e+00 x: 9.06e-01
# Sweep no. 7203 Average visits: 7.13e+03. Min/avg: 0.00e+00 x: 9.30e-01
# Sweep no. 8817 Average visits: 8.71e+03. Min/avg: 0.00e+00 x: 8.36e-01
# Sweep no. 10418 Average visits: 1.03e+04. Min/avg: 0.00e+00 x: 6.95e-01
# Sweep no. 11848 Average visits: 1.17e+04. Min/avg: 0.00e+00 x: 2.58e-01
# Sweep no. 13204 Average visits: 1.31e+04. Min/avg: 3.37e-01 x: 2.03e-01
# Sweep no. 14722 Average visits: 1.46e+04. Min/avg: 4.05e-01 x: 6.09e-01
# Sweep no. 16313 Average visits: 1.62e+04. Min/avg: 3.73e-01 x: 5.16e-01
# Sweep no. 17938 Average visits: 1.78e+04. Min/avg: 3.62e-01 x: 8.28e-01
# Sweep no. 19572 Average visits: 1.94e+04. Min/avg: 3.88e-01 x: 1.02e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1607 Average visits: 1.59e+03. Min/avg: 7.07e-01 x: 2.97e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1620 Average visits: 1.60e+03. Min/avg: 4.71e-01 x: 3.67e-01
# Sweep no. 3239 Average visits: 3.20e+03. Min/avg: 6.73e-01 x: 3.05e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1605 Average visits: 1.59e+03. Min/avg: 1.78e-01 x: 1.56e-01
# Sweep no. 3244 Average visits: 3.21e+03. Min/avg: 3.96e-01 x: 3.91e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1672 Average visits: 1.66e+03. Min/avg: 4.94e-02 x: 7.58e-01
# Sweep no. 3295 Average visits: 3.27e+03. Min/avg: 4.00e-01 x: 5.47e-02
# Sweep no. 4900 Average visits: 4.86e+03. Min/avg: 6.96e-01 x: 1.41e-01
# Sweep no. 6537 Average visits: 6.48e+03. Min/avg: 6.17e-01 x: 4.22e-01
# Sweep no. 8195 Average visits: 8.13e+03. Min/avg: 7.17e-01 x: 9.14e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1616 Average visits: 1.62e+03. Min/avg: 0.00e+00 x: 3.05e-01
# Sweep no. 3233 Average visits: 3.21e+03. Min/avg: 7.00e-01 x: 1.00e+00
# Sweep no. 4840 Average visits: 4.81e+03. Min/avg: 6.85e-01 x: 3.52e-01
# Sweep no. 6471 Average visits: 6.44e+03. Min/avg: 6.80e-01 x: 9.77e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1678 Average visits: 1.64e+03. Min/avg: 0.00e+00 x: 7.73e-01
# Sweep no. 3320 Average visits: 3.26e+03. Min/avg: 4.91e-03 x: 1.33e-01
# Sweep no. 4938 Average visits: 4.88e+03. Min/avg: 1.78e-01 x: 2.66e-01
# Sweep no. 6543 Average visits: 6.48e+03. Min/avg: 4.07e-01 x: 9.38e-02
# Sweep no. 8191 Average visits: 8.13e+03. Min/avg: 5.47e-01 x: 6.33e-01
# Sweep no. 9806 Average visits: 9.72e+03. Min/avg: 5.42e-01 x: 4.61e-01
# Sweep no. 11473 Average visits: 1.14e+04. Min/avg: 6.62e-01 x: 4.84e-01
# Sweep no. 13126 Average visits: 1.30e+04. Min/avg: 7.58e-01 x: 3.91e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1679 Average visits: 1.68e+03. Min/avg: 0.00e+00 x: 2.42e-01
# Sweep no. 3287 Average visits: 3.25e+03. Min/avg: 3.80e-01 x: 7.42e-01
# Sweep no. 4896 Average visits: 4.85e+03. Min/avg: 3.20e-01 x: 5.78e-01
# Sweep no. 6537 Average visits: 6.49e+03. Min/avg: 4.14e-01 x: 2.50e-01
# Sweep no. 8140 Average visits: 8.09e+03. Min/avg: 4.99e-01 x: 3.44e-01
# Sweep no. 9743 Average visits: 9.68e+03. Min/avg: 6.39e-01 x: 5.62e-01
# Sweep no. 11336 Average visits: 1.12e+04. Min/avg: 5.74e-01 x: 6.09e-01
# Sweep no. 12947 Average visits: 1.28e+04. Min/avg: 7.38e-01 x: 4.38e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1606 Average visits: 1.61e+03. Min/avg: 0.00e+00 x: 4.61e-01
# Sweep no. 3249 Average visits: 3.24e+03. Min/avg: 1.78e-01 x: 7.34e-01
# Sweep no. 4935 Average visits: 4.90e+03. Min/avg: 1.18e-01 x: 7.11e-01
# Sweep no. 6609 Average visits: 6.57e+03. Min/avg: 3.34e-01 x: 1.09e-01
# Sweep no. 8235 Average visits: 8.20e+03. Min/avg: 3.39e-01 x: 2.19e-01
# Sweep no. 9889 Average visits: 9.85e+03. Min/avg: 2.82e-01 x: 1.02e-01
# Sweep no. 11542 Average visits: 1.15e+04. Min/avg: 3.62e-01 x: 6.64e-01
# Sweep no. 13186 Average visits: 1.31e+04. Min/avg: 4.65e-01 x: 4.22e-01
# Sweep no. 14818 Average visits: 1.48e+04. Min/avg: 6.55e-01 x: 1.17e-01
# Sweep no. 16446 Average visits: 1.64e+04. Min/avg: 6.75e-01 x: 7.81e-01
# Sweep no. 18068 Average visits: 1.80e+04. Min/avg: 6.96e-01 x: 2.42e-01
# Sweep no. 19678 Average visits: 1.96e+04. Min/avg: 6.85e-01 x: 5.78e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1664 Average visits: 1.59e+03. Min/avg: 0.00e+00 x: 7.34e-01
# Sweep no. 3277 Average visits: 3.21e+03. Min/avg: 1.39e-01 x: 6.80e-01
# Sweep no. 4943 Average visits: 4.85e+03. Min/avg: 9.18e-02 x: 4.69e-01
# Sweep no. 6631 Average visits: 6.53e+03. Min/avg: 1.41e-01 x: 7.34e-01
# Sweep no. 8289 Average visits: 8.13e+03. Min/avg: 1.14e-01 x: 7.03e-01
# Sweep no. 9942 Average visits: 9.77e+03. Min/avg: 9.45e-02 x: 9.69e-01
# Sweep no. 11556 Average visits: 1.14e+04. Min/avg: 8.85e-02 x: 3.36e-01
# Sweep no. 13175 Average visits: 1.30e+04. Min/avg: 7.74e-02 x: 6.95e-01
# Sweep no. 14791 Average visits: 1.46e+04. Min/avg: 6.91e-02 x: 3.91e-01
# Sweep no. 16437 Average visits: 1.62e+04. Min/avg: 6.21e-02 x: 5.94e-01
# Sweep no. 18108 Average visits: 1.79e+04. Min/avg: 5.63e-02 x: 6.80e-01
# Sweep no. 19787 Average visits: 1.95e+04. Min/avg: 5.16e-02 x: 9.92e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1685 Average visits: 1.67e+03. Min/avg: 5.60e-01 x: 1.00e+00
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1636 Average visits: 1.62e+03. Min/avg: 1.54e-01 x: 2.42e-01
# Sweep no. 3301 Average visits: 3.28e+03. Min/avg: 7.57e-01 x: 8.67e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1677 Average visits: 1.66e+03. Min/avg: 5.73e-01 x: 6.09e-01
# Sweep no. 3349 Average visits: 3.33e+03. Min/avg: 4.84e-01 x: 8.59e-02
# Sweep no. 5017 Average visits: 4.99e+03. Min/avg: 6.67e-01 x: 7.19e-01
# Sweep no. 6618 Average visits: 6.59e+03. Min/avg: 6.82e-01 x: 6.72e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1640 Average visits: 1.63e+03. Min/avg: 7.24e-02 x: 1.48e-01
# Sweep no. 3282 Average visits: 3.27e+03. Min/avg: 1.89e-01 x: 9.45e-01
# Sweep no. 4924 Average visits: 4.87e+03. Min/avg: 3.07e-01 x: 3.91e-02
# Sweep no. 6518 Average visits: 6.46e+03. Min/avg: 5.96e-01 x: 2.27e-01
# Sweep no. 8144 Average visits: 8.06e+03. Min/avg: 7.33e-01 x: 5.94e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1657 Average visits: 1.66e+03. Min/avg: 0.00e+00 x: 4.69e-02
# Sweep no. 3305 Average visits: 3.31e+03. Min/avg: 0.00e+00 x: 2.27e-01
# Sweep no. 4922 Average visits: 4.91e+03. Min/avg: 1.30e-01 x: 4.30e-01
# Sweep no. 6553 Average visits: 6.53e+03. Min/avg: 3.22e-01 x: 9.69e-01
# Sweep no. 8195 Average visits: 8.15e+03. Min/avg: 6.57e-01 x: 5.16e-01
# Sweep no. 9801 Average visits: 9.76e+03. Min/avg: 5.49e-01 x: 3.12e-01
# Sweep no. 11432 Average visits: 1.14e+04. Min/avg: 4.70e-01 x: 1.33e-01
# Sweep no. 13038 Average visits: 1.30e+04. Min/avg: 6.33e-01 x: 9.45e-01
# Sweep no. 14660 Average visits: 1.46e+04. Min/avg: 6.90e-01 x: 6.80e-01
# Sweep no. 16327 Average visits: 1.62e+04. Min/avg: 7.12e-01 x: 3.44e-01
# Sweep no. 17965 Average visits: 1.78e+04. Min/avg: 7.11e-01 x: 7.97e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1670 Average visits: 1.66e+03. Min/avg: 1.50e-01 x: 5.47e-01
# Sweep no. 3276 Average visits: 3.27e+03. Min/avg: 2.37e-01 x: 1.41e-01
# Sweep no. 4883 Average visits: 4.88e+03. Min/avg: 1.59e-01 x: 4.69e-02
# Sweep no. 6572 Average visits: 6.56e+03. Min/avg: 2.05e-01 x: 8.28e-01
# Sweep no. 8216 Average visits: 8.17e+03. Min/avg: 7.08e-01 x: 8.75e-01
# Sweep no. 9841 Average visits: 9.79e+03. Min/avg: 6.51e-01 x: 3.28e-01
# Sweep no. 11511 Average visits: 1.15e+04. Min/avg: 5.56e-01 x: 2.89e-01
# Sweep no. 13185 Average visits: 1.31e+04. Min/avg: 5.62e-01 x: 2.73e-01
# Sweep no. 14818 Average visits: 1.48e+04. Min/avg: 5.00e-01 x: 1.72e-01
# Sweep no. 16478 Average visits: 1.64e+04. Min/avg: 4.49e-01 x: 1.17e-01
# Sweep no. 18156 Average visits: 1.81e+04. Min/avg: 5.63e-01 x: 7.58e-01
# Sweep no. 19824 Average visits: 1.97e+04. Min/avg: 6.57e-01 x: 7.73e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1667 Average visits: 1.65e+03. Min/avg: 0.00e+00 x: 1.48e-01
# Sweep no. 3336 Average visits: 3.32e+03. Min/avg: 2.25e-01 x: 5.16e-01
# Sweep no. 4968 Average visits: 4.93e+03. Min/avg: 1.52e-01 x: 8.52e-01
# Sweep no. 6656 Average visits: 6.60e+03. Min/avg: 1.13e-01 x: 3.75e-01
# Sweep no. 8300 Average visits: 8.25e+03. Min/avg: 5.42e-01 x: 3.52e-01
# Sweep no. 9939 Average visits: 9.88e+03. Min/avg: 6.33e-01 x: 2.73e-01
# Sweep no. 11561 Average visits: 1.15e+04. Min/avg: 5.44e-01 x: 7.34e-01
# Sweep no. 13191 Average visits: 1.31e+04. Min/avg: 5.25e-01 x: 3.91e-02
# Sweep no. 14809 Average visits: 1.47e+04. Min/avg: 4.67e-01 x: 7.81e-03
# Sweep no. 16480 Average visits: 1.64e+04. Min/avg: 5.58e-01 x: 8.67e-01
# Sweep no. 18102 Average visits: 1.80e+04. Min/avg: 6.79e-01 x: 7.11e-01
# Sweep no. 19693 Average visits: 1.95e+04. Min/avg: 7.05e-01 x: 4.92e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1619 Average visits: 1.62e+03. Min/avg: 0.00e+00 x: 3.44e-01
# Sweep no. 3229 Average visits: 3.20e+03. Min/avg: 1.23e-01 x: 7.81e-01
# Sweep no. 4845 Average visits: 4.80e+03. Min/avg: 8.21e-02 x: 4.69e-01
# Sweep no. 6503 Average visits: 6.46e+03. Min/avg: 2.20e-01 x: 2.50e-01
# Sweep no. 8166 Average visits: 8.11e+03. Min/avg: 1.75e-01 x: 2.42e-01
# Sweep no. 9804 Average visits: 9.75e+03. Min/avg: 4.91e-01 x: 1.09e-01
# Sweep no. 11422 Average visits: 1.14e+04. Min/avg: 5.67e-01 x: 9.77e-01
# Sweep no. 13092 Average visits: 1.30e+04. Min/avg: 6.64e-01 x: 2.34e-02
# Sweep no. 14740 Average visits: 1.47e+04. Min/avg: 5.89e-01 x: 1.56e-01
# Sweep no. 16357 Average visits: 1.63e+04. Min/avg: 5.31e-01 x: 2.27e-01
# Sweep no. 18006 Average visits: 1.79e+04. Min/avg: 4.82e-01 x: 5.47e-01
# Sweep no. 19636 Average visits: 1.96e+04. Min/avg: 4.42e-01 x: 6.25e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1720 Average visits: 1.71e+03. Min/avg: 7.27e-01 x: 8.52e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1636 Average visits: 1.63e+03. Min/avg: 5.37e-01 x: 6.09e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1660 Average visits: 1.65e+03. Min/avg: 4.94e-01 x: 2.81e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1565 Average visits: 1.55e+03. Min/avg: 2.34e-01 x: 7.89e-01
# Sweep no. 3129 Average visits: 3.10e+03. Min/avg: 5.08e-01 x: 1.72e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1559 Average visits: 1.55e+03. Min/avg: 1.18e-01 x: 3.91e-01
# Sweep no. 3127 Average visits: 3.10e+03. Min/avg: 5.11e-01 x: 4.06e-01
# Sweep no. 4734 Average visits: 4.70e+03. Min/avg: 7.69e-01 x: 5.62e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1564 Average visits: 1.56e+03. Min/avg: 0.00e+00 x: 4.61e-01
# Sweep no. 3207 Average visits: 3.19e+03. Min/avg: 3.86e-01 x: 9.61e-01
# Sweep no. 4804 Average visits: 4.77e+03. Min/avg: 7.47e-01 x: 2.19e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1643 Average visits: 1.60e+03. Min/avg: 0.00e+00 x: 7.89e-01
# Sweep no. 3264 Average visits: 3.22e+03. Min/avg: 3.11e-04 x: 3.91e-02
# Sweep no. 4898 Average visits: 4.84e+03. Min/avg: 3.40e-01 x: 7.58e-01
# Sweep no. 6529 Average visits: 6.47e+03. Min/avg: 5.46e-01 x: 7.27e-01
# Sweep no. 8174 Average visits: 8.09e+03. Min/avg: 5.49e-01 x: 2.03e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1609 Average visits: 1.60e+03. Min/avg: 0.00e+00 x: 4.53e-01
# Sweep no. 3250 Average visits: 3.24e+03. Min/avg: 1.74e-01 x: 1.25e-01
# Sweep no. 4905 Average visits: 4.89e+03. Min/avg: 2.18e-01 x: 9.77e-01
# Sweep no. 6486 Average visits: 6.43e+03. Min/avg: 1.66e-01 x: 4.14e-01
# Sweep no. 8054 Average visits: 7.97e+03. Min/avg: 1.34e-01 x: 8.83e-01
# Sweep no. 9679 Average visits: 9.55e+03. Min/avg: 1.12e-01 x: 5.55e-01
# Sweep no. 11325 Average visits: 1.12e+04. Min/avg: 4.61e-01 x: 3.05e-01
# Sweep no. 12972 Average visits: 1.28e+04. Min/avg: 5.02e-01 x: 5.00e-01
# Sweep no. 14624 Average visits: 1.45e+04. Min/avg: 6.12e-01 x: 3.05e-01
# Sweep no. 16234 Average visits: 1.61e+04. Min/avg: 6.89e-01 x: 4.22e-01
# Sweep no. 17819 Average visits: 1.77e+04. Min/avg: 7.68e-01 x: 5.00e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1626 Average visits: 1.63e+03. Min/avg: 0.00e+00 x: 5.78e-01
# Sweep no. 3269 Average visits: 3.26e+03. Min/avg: 2.38e-01 x: 5.39e-01
# Sweep no. 4843 Average visits: 4.81e+03. Min/avg: 4.46e-01 x: 8.20e-01
# Sweep no. 6472 Average visits: 6.43e+03. Min/avg: 3.84e-01 x: 2.27e-01
# Sweep no. 8083 Average visits: 8.03e+03. Min/avg: 6.08e-01 x: 2.42e-01
# Sweep no. 9620 Average visits: 9.57e+03. Min/avg: 5.27e-01 x: 8.05e-01
# Sweep no. 11230 Average visits: 1.11e+04. Min/avg: 4.53e-01 x: 9.77e-01
# Sweep no. 12855 Average visits: 1.27e+04. Min/avg: 5.24e-01 x: 3.91e-01
# Sweep no. 14486 Average visits: 1.43e+04. Min/avg: 5.22e-01 x: 9.30e-01
# Sweep no. 16098 Average visits: 1.59e+04. Min/avg: 4.70e-01 x: 5.78e-01
# Sweep no. 17579 Average visits: 1.74e+04. Min/avg: 6.14e-01 x: 1.64e-01
# Sweep no. 19029 Average visits: 1.89e+04. Min/avg: 6.94e-01 x: 4.30e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1619 Average visits: 1.62e+03. Min/avg: 0.00e+00 x: 1.56e-02
# Sweep no. 3206 Average visits: 3.19e+03. Min/avg: 1.31e-01 x: 6.25e-01
# Sweep no. 4799 Average visits: 4.78e+03. Min/avg: 3.88e-01 x: 6.64e-01
# Sweep no. 6396 Average visits: 6.37e+03. Min/avg: 4.44e-01 x: 9.53e-01
# Sweep no. 7999 Average visits: 7.96e+03. Min/avg: 4.75e-01 x: 2.58e-01
# Sweep no. 9604 Average visits: 9.54e+03. Min/avg: 4.92e-01 x: 9.61e-01
# Sweep no. 11211 Average visits: 1.11e+04. Min/avg: 4.22e-01 x: 4.53e-01
# Sweep no. 12793 Average visits: 1.27e+04. Min/avg: 3.69e-01 x: 5.62e-01
# Sweep no. 14378 Average visits: 1.43e+04. Min/avg: 4.03e-01 x: 4.30e-01
# Sweep no. 16003 Average visits: 1.59e+04. Min/avg: 6.06e-01 x: 1.00e+00
# Sweep no. 17643 Average visits: 1.75e+04. Min/avg: 5.51e-01 x: 6.02e-01
# Sweep no. 19242 Average visits: 1.91e+04. Min/avg: 5.72e-01 x: 4.45e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1447 Average visits: 1.43e+03. Min/avg: 6.47e-01 x: 9.30e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1396 Average visits: 1.38e+03. Min/avg: 3.09e-01 x: 8.44e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1501 Average visits: 1.48e+03. Min/avg: 3.49e-01 x: 1.80e-01
# Sweep no. 2937 Average visits: 2.91e+03. Min/avg: 6.24e-01 x: 5.55e-01
# Sweep no. 4360 Average visits: 4.32e+03. Min/avg: 5.42e-01 x: 6.95e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1353 Average visits: 1.35e+03. Min/avg: 1.95e-01 x: 9.06e-01
# Sweep no. 2869 Average visits: 2.85e+03. Min/avg: 6.25e-01 x: 2.19e-01
# Sweep no. 4288 Average visits: 4.26e+03. Min/avg: 7.23e-01 x: 9.92e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1603 Average visits: 1.57e+03. Min/avg: 0.00e+00 x: 5.00e-01
# Sweep no. 3238 Average visits: 3.21e+03. Min/avg: 1.86e-01 x: 6.64e-01
# Sweep no. 4871 Average visits: 4.82e+03. Min/avg: 7.02e-01 x: 8.91e-01
# Sweep no. 6479 Average visits: 6.41e+03. Min/avg: 7.37e-01 x: 7.81e-02
# Sweep no. 8089 Average visits: 8.01e+03. Min/avg: 7.48e-01 x: 8.98e-01
# Sweep no. 9698 Average visits: 9.61e+03. Min/avg: 6.82e-01 x: 9.38e-02
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1655 Average visits: 1.64e+03. Min/avg: 1.01e-01 x: 6.02e-01
# Sweep no. 3324 Average visits: 3.28e+03. Min/avg: 2.90e-01 x: 8.20e-01
# Sweep no. 4983 Average visits: 4.94e+03. Min/avg: 3.10e-01 x: 2.81e-01
# Sweep no. 6614 Average visits: 6.56e+03. Min/avg: 4.71e-01 x: 2.50e-01
# Sweep no. 8244 Average visits: 8.18e+03. Min/avg: 6.79e-01 x: 1.09e-01
# Sweep no. 9890 Average visits: 9.80e+03. Min/avg: 7.49e-01 x: 7.81e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1601 Average visits: 1.60e+03. Min/avg: 0.00e+00 x: 2.03e-01
# Sweep no. 3227 Average visits: 3.23e+03. Min/avg: 0.00e+00 x: 4.69e-02
# Sweep no. 4790 Average visits: 4.79e+03. Min/avg: 0.00e+00 x: 8.12e-01
# Sweep no. 6446 Average visits: 6.42e+03. Min/avg: 4.34e-01 x: 5.23e-01
# Sweep no. 8091 Average visits: 8.04e+03. Min/avg: 6.07e-01 x: 4.22e-01
# Sweep no. 9703 Average visits: 9.64e+03. Min/avg: 6.97e-01 x: 7.42e-01
# Sweep no. 11353 Average visits: 1.13e+04. Min/avg: 6.43e-01 x: 5.47e-02
# Sweep no. 13005 Average visits: 1.29e+04. Min/avg: 7.69e-01 x: 1.56e-01
# Sweep no. 14624 Average visits: 1.45e+04. Min/avg: 7.42e-01 x: 8.20e-01
# Sweep no. 16234 Average visits: 1.61e+04. Min/avg: 6.70e-01 x: 8.44e-01
# Sweep no. 17868 Average visits: 1.77e+04. Min/avg: 7.55e-01 x: 1.48e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1620 Average visits: 1.62e+03. Min/avg: 0.00e+00 x: 3.52e-01
# Sweep no. 3249 Average visits: 3.25e+03. Min/avg: 0.00e+00 x: 1.95e-01
# Sweep no. 4880 Average visits: 4.88e+03. Min/avg: 0.00e+00 x: 6.80e-01
# Sweep no. 9756 Average visits: 9.70e+03. Min/avg: 5.49e-01 x: 1.72e-01
# Sweep no. 11364 Average visits: 1.13e+04. Min/avg: 5.63e-01 x: 4.77e-01
# Sweep no. 12954 Average visits: 1.29e+04. Min/avg: 5.67e-01 x: 8.98e-01
# Sweep no. 14568 Average visits: 1.45e+04. Min/avg: 5.34e-01 x: 4.69e-01
# Sweep no. 16192 Average visits: 1.61e+04. Min/avg: 6.29e-01 x: 4.22e-01
# Sweep no. 17785 Average visits: 1.77e+04. Min/avg: 6.76e-01 x: 8.05e-01
# Sweep no. 19406 Average visits: 1.93e+04. Min/avg: 6.81e-01 x: 6.56e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1617 Average visits: 1.57e+03. Min/avg: 0.00e+00 x: 1.17e-01
# Sweep no. 3232 Average visits: 3.19e+03. Min/avg: 1.56e-01 x: 5.31e-01
# Sweep no. 4846 Average visits: 4.80e+03. Min/avg: 2.65e-01 x: 3.05e-01
# Sweep no. 6511 Average visits: 6.47e+03. Min/avg: 2.90e-01 x: 1.88e-01
# Sweep no. 8123 Average visits: 8.08e+03. Min/avg: 2.32e-01 x: 2.81e-01
# Sweep no. 9728 Average visits: 9.69e+03. Min/avg: 1.94e-01 x: 1.56e-01
# Sweep no. 11363 Average visits: 1.13e+04. Min/avg: 1.66e-01 x: 1.02e-01
# Sweep no. 12971 Average visits: 1.29e+04. Min/avg: 1.49e-01 x: 5.31e-01
# Sweep no. 14587 Average visits: 1.45e+04. Min/avg: 1.61e-01 x: 4.06e-01
# Sweep no. 16238 Average visits: 1.61e+04. Min/avg: 3.48e-01 x: 7.97e-01
# Sweep no. 17887 Average visits: 1.78e+04. Min/avg: 5.14e-01 x: 1.80e-01
# Sweep no. 19536 Average visits: 1.94e+04. Min/avg: 4.70e-01 x: 2.42e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1648 Average visits: 1.63e+03. Min/avg: 7.69e-01 x: 3.52e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1654 Average visits: 1.63e+03. Min/avg: 2.42e-01 x: 8.91e-01
# Sweep no. 3292 Average visits: 3.27e+03. Min/avg: 7.60e-01 x: 8.44e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1603 Average visits: 1.59e+03. Min/avg: 5.53e-01 x: 9.92e-01
# Sweep no. 3200 Average visits: 3.17e+03. Min/avg: 7.13e-01 x: 9.30e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1613 Average visits: 1.61e+03. Min/avg: 0.00e+00 x: 6.25e-01
# Sweep no. 3232 Average visits: 3.22e+03. Min/avg: 4.83e-01 x: 2.03e-01
# Sweep no. 4839 Average visits: 4.82e+03. Min/avg: 6.36e-01 x: 2.50e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1588 Average visits: 1.57e+03. Min/avg: 1.32e-01 x: 8.28e-01
# Sweep no. 3214 Average visits: 3.19e+03. Min/avg: 5.74e-01 x: 4.30e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1551 Average visits: 1.55e+03. Min/avg: 0.00e+00 x: 9.38e-01
# Sweep no. 3161 Average visits: 3.15e+03. Min/avg: 3.99e-01 x: 6.02e-01
# Sweep no. 4808 Average visits: 4.79e+03. Min/avg: 4.92e-01 x: 6.02e-01
# Sweep no. 6430 Average visits: 6.41e+03. Min/avg: 3.70e-01 x: 9.61e-01
# Sweep no. 8035 Average visits: 7.98e+03. Min/avg: 6.63e-01 x: 2.27e-01
# Sweep no. 9671 Average visits: 9.61e+03. Min/avg: 6.68e-01 x: 4.14e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1606 Average visits: 1.57e+03. Min/avg: 0.00e+00 x: 7.27e-01
# Sweep no. 3213 Average visits: 3.17e+03. Min/avg: 3.21e-01 x: 2.89e-01
# Sweep no. 4810 Average visits: 4.75e+03. Min/avg: 4.25e-01 x: 6.41e-01
# Sweep no. 6387 Average visits: 6.32e+03. Min/avg: 5.91e-01 x: 3.91e-02
# Sweep no. 8008 Average visits: 7.94e+03. Min/avg: 6.15e-01 x: 8.12e-01
# Sweep no. 9674 Average visits: 9.58e+03. Min/avg: 6.97e-01 x: 9.45e-01
# Sweep no. 11291 Average visits: 1.12e+04. Min/avg: 7.34e-01 x: 3.28e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1655 Average visits: 1.66e+03. Min/avg: 0.00e+00 x: 5.94e-01
# Sweep no. 3270 Average visits: 3.27e+03. Min/avg: 2.74e-01 x: 8.91e-01
# Sweep no. 4894 Average visits: 4.89e+03. Min/avg: 2.54e-01 x: 2.34e-02
# Sweep no. 6504 Average visits: 6.48e+03. Min/avg: 6.73e-01 x: 8.67e-01
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1618 Average visits: 1.60e+03. Min/avg: 0.00e+00 x: 4.30e-01
# Sweep no. 3218 Average visits: 3.21e+03. Min/avg: 8.80e-02 x: 0.00e+00
# Sweep no. 4809 Average visits: 4.80e+03. Min/avg: 5.88e-02 x: 2.97e-01
# Sweep no. 6386 Average visits: 6.37e+03. Min/avg: 4.43e-02 x: 2.66e-01
# Sweep no. 8028 Average visits: 8.00e+03. Min/avg: 1.80e-01 x: 7.89e-01
# Sweep no. 9652 Average visits: 9.57e+03. Min/avg: 5.52e-01 x: 9.61e-01
# Sweep no. 11257 Average visits: 1.12e+04. Min/avg: 6.54e-01 x: 1.17e-01
# Sweep no. 12859 Average visits: 1.28e+04. Min/avg: 6.98e-01 x: 9.14e-01
# Sweep no. 14496 Average visits: 1.44e+04. Min/avg: 7.32e-01 x: 1.02e-01
# Sweep no. 16115 Average visits: 1.60e+04. Min/avg: 6.58e-01 x: 3.67e-01
# Sweep no. 17751 Average visits: 1.76e+04. Min/avg: 7.24e-01 x: 4.69e-01
# Sweep no. 19382 Average visits: 1.93e+04. Min/avg: 6.62e-01 x: 4.69e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Sweep no. 1645 Average visits: 1.65e+03. Min/avg: 0.00e+00 x: 5.94e-01
# Sweep no. 3307 Average visits: 3.28e+03. Min/avg: 4.14e-02 x: 9.92e-01
# Sweep no. 4946 Average visits: 4.86e+03. Min/avg: 2.80e-02 x: 9.77e-01
# Sweep no. 6590 Average visits: 6.49e+03. Min/avg: 1.86e-01 x: 3.44e-01
# Sweep no. 8257 Average visits: 8.16e+03. Min/avg: 3.45e-01 x: 6.72e-01
# Sweep no. 9915 Average visits: 9.74e+03. Min/avg: 2.89e-01 x: 8.67e-01
# Sweep no. 11554 Average visits: 1.13e+04. Min/avg: 2.86e-01 x: 6.80e-01
# Sweep no. 13187 Average visits: 1.30e+04. Min/avg: 2.50e-01 x: 8.91e-01
# Sweep no. 14814 Average visits: 1.46e+04. Min/avg: 2.72e-01 x: 4.14e-01
# Sweep no. 16476 Average visits: 1.62e+04. Min/avg: 4.31e-01 x: 8.98e-01
# Sweep no. 18111 Average visits: 1.78e+04. Min/avg: 4.12e-01 x: 1.56e-02
# Sweep no. 19749 Average visits: 1.95e+04. Min/avg: 4.58e-01 x: 3.36e-01
# Reached max number of sweeps...
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec
# Results from metadynamics sampling written to aucu_metadyn.json
# Starting metadynamics sampling...
# Writing result to aucu_metadyn.json every 30 sec

# %%
from scipy.spatial import ConvexHull

boundaries = []

for ind in range(41):
    print(temps[ind])
    concs = np.linspace(0,1.0,129)
    plt.plot(concs,pots[ind,:])

    points = np.concatenate((concs.reshape(-1,1),pots[ind,:].reshape(-1,1)),axis = 1)
    hull = ConvexHull(points)


    plt.plot(points[hull.vertices,0], points[hull.vertices,1], 'ro')

    plt.show()
    
    cutoff = concs[1]*7
    
    hull_points = points[hull.vertices,:]
    hull_points = np.sort(hull_points,axis=0)
    #print(hull_points)
    curr_boundary = []
    for j in range(1,hull.vertices.shape[0]):
        if (hull_points[j,0]-hull_points[j-1,0] > cutoff):
            curr_boundary.append(hull_points[j-1,0])
            curr_boundary.append(hull_points[j,0])
            
    print(curr_boundary)
    boundaries.append(curr_boundary)
# Out:
# 200.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 1.0]
# 225.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 0.9921875]
# 250.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 0.984375]
# 275.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 0.9765625]
# 300.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.75, 0.9609375]
# 325.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.7578125, 0.9453125]
# 350.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.75, 0.765625, 0.921875]
# 375.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.7578125, 0.765625, 0.890625]
# 400.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.7578125, 0.7578125, 0.8671875]
# 425.0
# [0.0, 0.25, 0.25, 0.5, 0.5, 0.765625, 0.765625, 0.84375]
# 450.0
# [0.0078125, 0.25, 0.25, 0.5, 0.5, 0.8203125]
# 475.0
# [0.0078125, 0.25, 0.25, 0.5, 0.5, 0.8125]
# 500.0
# [0.0078125, 0.25, 0.25, 0.5, 0.5, 0.8046875]
# 525.0
# [0.0078125, 0.25, 0.25, 0.5, 0.5, 0.7890625]
# 550.0
# [0.015625, 0.25, 0.25, 0.5, 0.5, 0.78125]
# 575.0
# [0.015625, 0.25, 0.25, 0.5, 0.5, 0.7578125]
# 600.0
# [0.03125, 0.25, 0.25, 0.5, 0.5, 0.75]
# 625.0
# [0.03125, 0.25, 0.25, 0.5, 0.5, 0.71875]
# 650.0
# [0.0390625, 0.25, 0.2578125, 0.5, 0.5, 0.7109375]
# 675.0
# [0.0546875, 0.25, 0.2578125, 0.5, 0.5, 0.6796875]
# 700.0
# [0.0625, 0.2421875, 0.2578125, 0.5, 0.5, 0.640625]
# 725.0
# [0.078125, 0.2421875, 0.265625, 0.4921875, 0.5, 0.6015625]
# 750.0
# [0.0859375, 0.234375, 0.2578125, 0.4921875, 0.5, 0.578125]
# 775.0
# [0.1015625, 0.2421875, 0.265625, 0.421875]
# 800.0
# [0.1328125, 0.234375, 0.2734375, 0.3984375]
# 825.0
# [0.1484375, 0.2421875, 0.2890625, 0.359375]
# 850.0
# []
# 875.0
# []
# 900.0
# []
# 925.0
# []
# 950.0
# []
# 975.0
# []
# 1000.0
# []
# 1025.0
# []
# 1050.0
# []
# 1075.0
# []
# 1100.0
# []
# 1125.0
# []
# 1150.0
# []
# 1175.0
# []
# 1200.0
# []

# %%
counter = 0
for t in temps:
    curr_temps = np.ones((2))*t
    curr_temps_b = np.ones((len(boundaries[counter])))*t
    for j in range(int(len(boundaries[counter])/2)):
        cb = []
        cb.append(boundaries[counter][2*j])
        cb.append(boundaries[counter][2*j+1])
        plt.plot(cb,curr_temps,color='red',alpha=0.25)
    plt.scatter(boundaries[counter],curr_temps_b,color='red')
    counter += 1
    
plt.show()

# %%
concs_AR = np.loadtxt(open("CuAu_128.csv", "rb"), delimiter=",", skiprows=0)

# %%
from scipy import interpolate

boundary_one = []
boundary_two = []
boundary_three = []
boundary_four = []
boundary_five = []
boundary_six = []
boundary_seven = []
boundary_top = []
boundary_right = []
boundary_ect = []
boundary_peri = []

boundary_cong_melt = []

counter = 0
for t in temps:
    if t <= 825:
        curr_point_one = [boundaries[counter][0],t]
        curr_point_two = [boundaries[counter][1],t]
        curr_point_three = [boundaries[counter][2],t]
        boundary_one.append(curr_point_one)
        boundary_two.append(curr_point_two)
        boundary_three.append(curr_point_three)
        
    if t <= 750:
        curr_point_right = [boundaries[counter][-1],t]
        boundary_right.append(curr_point_right)
        boundary_four.append([boundaries[counter][3],t])
        boundary_five.append([boundaries[counter][4],t])
        
    if t == 825:
        boundary_top.append([boundaries[counter][0],t])
        boundary_top.append([boundaries[counter][1],t])
        boundary_top.append([boundaries[counter][2],t])
        boundary_top.append([boundaries[counter][3],t])
        
    if t == 750:
        boundary_ect.append([boundaries[counter][-1],t])
        boundary_ect.append([boundaries[counter][-2],t])
        boundary_ect.append([boundaries[counter][-3],t])
        boundary_ect.append([boundaries[counter][-4],t])
        
    if t <= 425:
        boundary_six.append([boundaries[counter][4],t])
        boundary_seven.append([boundaries[counter][5],t])
        
    if t == 425:
        boundary_peri.append([boundaries[counter][-1],t])
        boundary_peri.append([boundaries[counter][-2],t])
        boundary_peri.append([boundaries[counter][-3]+0.000001,t])
        boundary_peri.append([boundaries[counter][-4],t])
        
    if t > 750 and t <= 825:
        boundary_cong_melt.append([boundaries[counter][-1],t])
        
    counter += 1
    
boundary_one = np.asarray(boundary_one)
tck, u = interpolate.splprep([boundary_one[:,0], boundary_one[:,1]], s=0)
new_points_one = interpolate.splev(u, tck)

boundary_two = np.asarray(boundary_two)
tck, u = interpolate.splprep([boundary_two[:,0], boundary_two[:,1]], s=0)
new_points_two = interpolate.splev(u, tck)

boundary_three = np.asarray(boundary_three)
tck, u = interpolate.splprep([boundary_three[:,0], boundary_three[:,1]], s=0)
new_points_three = interpolate.splev(u, tck)

boundary_right = np.asarray(boundary_right)
tck, u = interpolate.splprep([boundary_right[:,0], boundary_right[:,1]], s=0)
new_points_right = interpolate.splev(u, tck)

boundary_top = np.asarray(boundary_top)
tck, u = interpolate.splprep([boundary_top[:,0], boundary_top[:,1]], s=0)
new_points_top = interpolate.splev(u, tck)

boundary_ect = np.asarray(boundary_ect)
tck, u = interpolate.splprep([boundary_ect[:,0], boundary_ect[:,1]], s=0)
new_points_ect = interpolate.splev(u, tck)

boundary_four = np.asarray(boundary_four)
tck, u = interpolate.splprep([boundary_four[:,0], boundary_four[:,1]], s=0)
new_points_four = interpolate.splev(u, tck)

boundary_five = np.asarray(boundary_five)
tck, u = interpolate.splprep([boundary_five[:,0], boundary_five[:,1]], s=0)
new_points_five = interpolate.splev(u, tck)

boundary_six = np.asarray(boundary_six)
tck, u = interpolate.splprep([boundary_six[:,0], boundary_six[:,1]], s=0)
new_points_six = interpolate.splev(u, tck)

boundary_seven = np.asarray(boundary_seven)
tck, u = interpolate.splprep([boundary_seven[:,0], boundary_seven[:,1]], s=0)
new_points_seven = interpolate.splev(u, tck)

boundary_peri = np.asarray(boundary_peri)
tck, u = interpolate.splprep([boundary_peri[:,0], boundary_peri[:,1]], s=0)
new_points_peri = interpolate.splev(u, tck)


boundary_cong_melt = np.asarray(boundary_cong_melt)
tck, u = interpolate.splprep([boundary_cong_melt[:,0], boundary_cong_melt[:,1]], k=2,s=0)
new_points_cong_melt = interpolate.splev(u, tck)

# %%
mpl.rc('font',family='Arial')
hfont = {'fontname':'Arial'}

counter = 0
temps = np.linspace(200,1200,41)

for t in temps:
    curr_temps = np.ones((2))*t
    curr_temps_b = np.ones((len(boundaries[counter])))*t
    for j in range(int(len(boundaries[counter])/2)):
        cb = []
        cb.append(boundaries[counter][2*j])
        cb.append(boundaries[counter][2*j+1])
        plt.plot(cb,curr_temps,color='blue',alpha=0.25)
    plt.scatter(boundaries[counter],curr_temps_b,color='blue')
    counter += 1
    
plt.plot(new_points_one[0],new_points_one[1],color='black', linewidth=3)
plt.plot(new_points_two[0],new_points_two[1],color='black', linewidth=3)
plt.plot(new_points_three[0],new_points_three[1],color='black', linewidth=3)
plt.plot(new_points_right[0],new_points_right[1],color='black', linewidth=3)
plt.plot(new_points_top[0],new_points_top[1],color='black', linewidth=3)
plt.plot(new_points_ect[0],new_points_ect[1],color='black', linewidth=3)
plt.plot(new_points_four[0],new_points_four[1],color='black', linewidth=3)
plt.plot(new_points_five[0],new_points_five[1],color='black', linewidth=3)
plt.plot(new_points_six[0],new_points_six[1],color='black', linewidth=3)
plt.plot(new_points_seven[0],new_points_seven[1],color='black', linewidth=3)
plt.plot(new_points_peri[0],new_points_peri[1],color='black', linewidth=3)
plt.plot(new_points_cong_melt[0],new_points_cong_melt[1],color='black', linewidth=3)

# %%
plotter_temps = np.loadtxt(open("plotter_temps_june6_2.csv", "rb"), delimiter=",", skiprows=0)
plotter_concs = np.loadtxt(open("plotter_concs_june6_2.csv", "rb"), delimiter=",", skiprows=0)

plotter_temps_mid = np.loadtxt(open("plotter_temps_mid_june6_2.csv", "rb"), delimiter=",", skiprows=0)
plotter_concs_mid = np.loadtxt(open("plotter_concs_mid_june6_2.csv", "rb"), delimiter=",", skiprows=0)

path_x = np.loadtxt(open("Top_x_june6_2.csv", "rb"), delimiter=",", skiprows=0)
path_y = np.loadtxt(open("Top_Y_june6_2.csv", "rb"), delimiter=",", skiprows=0)

# %%
from matplotlib.colors import ListedColormap, LinearSegmentedColormap

#003f5c
#58508d
#bc5090
#ff6361
#ffa600
N = 5
newcolors = []
newcolors.append((0,63,92))
newcolors.append((88,80,141)) 
newcolors.append((188,80,144)) 
newcolors.append((255,99,97)) 
newcolors.append((255,166,0)) 

newcolors_norm = []
for i in newcolors:
    curr = np.asarray(i)
    print(curr)
    curr = curr/255.0
    curr = tuple(curr)
    newcolors_norm.append(curr)

cmap_name = 'my_list'
newcmp = LinearSegmentedColormap.from_list(cmap_name,newcolors_norm)
# Out:
# [ 0 63 92]
# [ 88  80 141]
# [188  80 144]
# [255  99  97]
# [255 166   0]

# %%
class AnyObjectHandler(HandlerBase):
    def create_artists(self, legend, orig_handle,
                       x0, y0, width, height, fontsize, trans):
        l1 = plt.Line2D([x0,y0+width], [0.7*height,0.7*height], 
                                                linestyle='--', color='k')
        l2 = plt.Line2D([x0,y0+width], [0.3*height,0.3*height], color='r')
        return [l1, l2]

# %%
import six
from matplotlib import pyplot as plt
import numpy as np
from matplotlib.legend_handler import HandlerLineCollection
import matplotlib.collections as mcol
from matplotlib.lines import Line2D

class HandlerDashedLines(HandlerLineCollection):
    """
    Custom Handler for LineCollection instances.
    """
    def create_artists(self, legend, orig_handle,
                       xdescent, ydescent, width, height, fontsize, trans):
        # figure out how many lines there are
        numlines = len(orig_handle.get_segments())
        xdata, xdata_marker = self.get_xdata(legend, xdescent, ydescent,
                                             width, height, fontsize)
        leglines = []
        # divide the vertical space where the lines will go
        # into equal parts based on the number of lines
        ydata = ((height) / (numlines + 1)) * np.ones(xdata.shape, float)
        # for each line, create the line at the proper location
        # and set the dash pattern
        for i in range(numlines):
            legline = Line2D(xdata, ydata * (numlines - i) - ydescent)
            self.update_prop(legline, orig_handle, legend)
            # set color, dash pattern, and linewidth to that
            # of the lines in linecollection
            try:
                color = orig_handle.get_colors()[i]
            except IndexError:
                color = orig_handle.get_colors()[0]
            try:
                dashes = orig_handle.get_dashes()[i]
            except IndexError:
                dashes = orig_handle.get_dashes()[0]
            try:
                lw = orig_handle.get_linewidths()[i]
            except IndexError:
                lw = orig_handle.get_linewidths()[0]
            if dashes[0] is not None:
                legline.set_dashes(dashes[1])
            legline.set_color(color)
            legline.set_transform(trans)
            legline.set_linewidth(3.0)
            leglines.append(legline)
        return leglines

# %%
import matplotlib as mpl
from matplotlib.legend_handler import HandlerTuple

#from matplotlib.legend_handler import HandlerDashedLines

mpl.rc('font',family='Arial')
hfont = {'fontname':'Arial'}
plt.rcParams["figure.figsize"] = (7,5)

c0 = 'dimgrey'
cl = newcmp(0.0)
c2 = newcmp(0.66666)

counter = 0
temps = np.linspace(200,1200,41)

for t in temps:
    curr_temps = np.ones((2))*t
    curr_temps_b = np.ones((len(boundaries[counter])))*t
    for j in range(int(len(boundaries[counter])/2)):
        cb = []
        cb.append(boundaries[counter][2*j])
        cb.append(boundaries[counter][2*j+1])
        #plt.plot(cb,curr_temps,color='red',alpha=0.25)
    #plt.scatter(boundaries[counter],curr_temps_b,color='orange')
    counter += 1
    
counter = 0
temps = np.linspace(200,1200,21)
for t in temps:
    if (counter < concs_AR.shape[0]):
        curr_temps = np.ones((41))*(t)
        plt.scatter(concs_AR[counter,:],curr_temps,color=c0,alpha=0.2)
    
    counter += 1
    
#plt.hlines(663,0.0,1.0,color='green')
#plt.hlines(683,0.0,1.0,color='green')


for i in range(len(plotter_concs)):
    plt.plot(plotter_concs[i],plotter_temps[i],color=c2,alpha=0.75)
    #plt.scatter(plotter_concs[i],plotter_temps[i],color='orange',alpha=1.0)
    
for i in range(len(plotter_concs_mid)):
    if i == 0:
        p1 = plt.plot(plotter_concs_mid[i],plotter_temps_mid[i],color=newcmp(0.3333),alpha=0.75)
    else:
        plt.plot(plotter_concs_mid[i],plotter_temps_mid[i],color=newcmp(0.3333),alpha=0.75)
p2 = plt.plot(path_x,path_y, color=c2,linewidth=3,label="Autoregressive")



plt.plot(new_points_one[0],new_points_one[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_two[0],new_points_two[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_three[0],new_points_three[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_right[0],new_points_right[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_top[0],new_points_top[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_ect[0],new_points_ect[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_four[0],new_points_four[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_five[0],new_points_five[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_six[0],new_points_six[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_seven[0],new_points_seven[1],"--",color=cl, linewidth=2.5)
plt.plot(new_points_peri[0],new_points_peri[1],"--",color=cl, linewidth=2.5)
p3 = plt.plot(new_points_cong_melt[0],new_points_cong_melt[1],"--",color=cl, linewidth=2.5,label="Metadynamics")


plt.ylabel("Temperature (K)",fontsize=16,fontname="Arial")
plt.xlabel("Composition (%Au)",fontsize=16,fontname="Arial")

plt.xticks(fontsize = 16,fontname = "Arial")
plt.yticks(fontsize = 16,fontname = "Arial")

#plt.legend([object], ['label'],
           #handler_map={object: AnyObjectHandler()},prop={'family': 'Arial','size':14},loc=1)

#plt.legend(prop={'family': 'Arial','size':14},loc=1)
colors = [newcmp(0.333333),newcmp(0.666666)]
styles = ['solid','solid']
lines = []
line = [[(0, 0)]]
# set up the proxy artist
lc = mcol.LineCollection(2 * line, linestyles=styles, colors=colors)

colors_2 = [newcmp(0.0)]
styles_2 = ['dashed']
lines_2 = []
line_2 = [[(0, 0)]]
# set up the proxy artist
lc_2 = mcol.LineCollection(1 * line, linestyles=styles_2, colors=colors_2)

plt.legend(prop={'family': 'Arial','size':14},loc=1)

plt.legend([(lc),(lc_2)], [('Autoregressive'),("Metadynamics")], handler_map={type(lc): HandlerDashedLines(),type(lc_2): HandlerDashedLines()},
           handlelength=2.5, handleheight=2,prop={'family': 'Arial','size':14},loc=1)


#plt.savefig('CuAuMeta_June6_2.pdf',bbox_inches='tight')


plt.show()
